# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:/train.csv")
df
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              142.0          0.000           0.000                 0.007
# 1              122.0          0.000           0.000                 0.006
# 2              129.0          0.005           0.003                 0.001
# 3              136.0          0.006           0.000                 0.008
# 4              144.0          0.000           0.000                 0.006
# ...              ...            ...             ...                   ...
# 1695           129.0          0.000           0.001                 0.006
# 1696           142.0          0.001           0.003                 0.001
# 1697           147.0          0.013           0.000                 0.010
# 1698           130.0          0.003           0.000                 0.007
# 1699           123.0          0.004           0.007                 0.000
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           142.0          0.000           0.000                 0.007
# 1           122.0          0.000           0.000                 0.006
# 2           129.0          0.005           0.003                 0.001
# 3           136.0          0.006           0.000                 0.008
# 4           144.0          0.000           0.000                 0.006
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.002                   0.0                       0.0
# 2                0.000                   0.0                       0.0
# 3                0.000                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          1700 non-null   float64
#  1   accelerations                                           1700 non-null   float64
#  2   fetal_movement                                          1700 non-null   float64
#  3   uterine_contractions                                    1700 non-null   float64
#  4   light_decelerations                                     1700 non-null   float64
#  5   severe_decelerations                                    1700 non-null   float64
#  6   prolongued_decelerations                                1700 non-null   float64
#  7   abnormal_short_term_variability                         1700 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
df.duplicated().sum()
# Out:
# 7

# %%
df.drop_duplicates(inplace=False)
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0              142.0          0.000           0.000                 0.007
# 1              122.0          0.000           0.000                 0.006
# 2              129.0          0.005           0.003                 0.001
# 3              136.0          0.006           0.000                 0.008
# 4              144.0          0.000           0.000                 0.006
# ...              ...            ...             ...                   ...
# 1695           129.0          0.000           0.001                 0.006
# 1696           142.0          0.001           0.003                 0.001
# 1697           147.0          0.013           0.000                 0.010
# 1698           130.0          0.003           0.000                 0.007
# 1699           123.0          0.004           0.007                 0.000
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     1693.000000    1693.000000     1693.000000           1693.000000
# mean       133.225044       0.003219        0.010239              0.004370
# std          9.873768       0.003892        0.050224              0.002939
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        159.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          1693.000000           1693.000000               1693.000000
# mean              0.001907              0.000004                  0.000158
# ...

# %%
import matplotlib.pyplot as plt
df.hist(figsize=(20,20))
plt.show()

# %%
import seaborn as sns
sns.countplot(df['fetal_health']) 
print(df.fetal_health.value_counts())
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 1.0    1317
# 2.0     235
# 3.0     141
# Name: fetal_health, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns 
sns.set(rc={'figure.figsize':(7,5)})
sns.distplot(df.fetal_health , bins=30)
plt.show()

# %%
corr = df.corr() 
plt.figure(figsize=(30,30))
sns.heatmap(corr, annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
y= df["fetal_health"].values
x= df.drop(["fetal_health"], axis=1).values
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=5)
print("No. of training samples : ",len(x_train))
print("No. of test samples : ",len(x_test))
# Out:
# No. of training samples :  1185
# No. of test samples :  508

# %% [markdown]
# ## Run from here

# %%
# !pip install pyforest
import pyforest
train_df = pd.read_csv('traindata.csv')
validation_df = pd.read_csv('validation test.csv')
test_df = pd.read_csv('evaluation test.csv')

# %%
print(" train data shape:",train_df.shape)
print(" validation data shape:",validation_df.shape)
print(" test data shape:",test_df.shape)
# Out:
#  train data shape: (1700, 22)
#  validation data shape: (426, 21)
#  test data shape: (426, 21)

# %%
train_df.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
train_df_target = train_df['fetal_health']
train_df_features = train_df.drop(['fetal_health'],axis=1)

# %%
## Scaling the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train_df_features)
# Out:
# StandardScaler()

# %%
scaled_training = scaler.transform(train_df_features)
scaled_validation = scaler.transform(validation_df)
scaled_test = scaler.transform(test_df)

# %%
## Model Building
## Logistic Regression

log_classifier = LogisticRegression()
log_classifier.fit(train_df_features,train_df_target)
log_predict = log_classifier.predict(train_df_features)
print("accuracy: ",metrics.accuracy_score(log_predict,train_df_target))
# Out:
# accuracy:  0.8652941176470588

# %%
## Model Building
## knn classifier
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier()
knn_classifier.fit(train_df_features,train_df_target)
knn_predict = knn_classifier.predict(train_df_features)
print("accuracy: ",metrics.accuracy_score(knn_predict,train_df_target))
# Out:
# accuracy:  0.9288235294117647

# %%
## NBclassifier
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(train_df_features,train_df_target)
gnb_predict = gnb.predict(train_df_features)
print("accuracy: ",metrics.accuracy_score(gnb_predict,train_df_target))
# Out:
# accuracy:  0.8123529411764706

# %%
## SVM classier

from sklearn.svm import SVC

svc = SVC()
svc.fit(train_df_features,train_df_target)
svc_predict = svc.predict(train_df_features)
print("accuracy: ",metrics.accuracy_score(svc_predict,train_df_target))
# Out:
# accuracy:  0.8552941176470589

# %% [markdown]
# ### From the above  four result KNN classifier seems to be giving the best predictions among all other models  so will take knn best fit this data

# %%
from sklearn.metrics import make_scorer, f1_score, recall_score, precision_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print("\n Confustion Matrix : \n",confusion_matrix(knn_predict,train_df_target))
print("\n")
print("\n")
print(classification_report(knn_predict,train_df_target))
print("accuracy: ",metrics.accuracy_score(knn_predict,train_df_target))
# Out:
#  Confustion Matrix :
#  [[1299   69   13]
#  [  20  163   11]
#  [   4    4  117]]
#
#
#
#
#               precision    recall  f1-score   support
#
#            1       0.98      0.94      0.96      1381
#            2       0.69      0.84      0.76       194
#            3       0.83      0.94      0.88       125
#
#     accuracy                           0.93      1700
#    macro avg       0.83      0.91      0.87      1700
# weighted avg       0.94      0.93      0.93      1700
# accuracy:  0.9288235294117647

# %%
knn_classifier_test = knn_classifier.predict(test_df)
result = pd.DataFrame(knn_classifier_test)
result.to_csv('Sample_test_result.csv')

# %%
display(result)
# Out:
#      0
# 0    1
# 1    1
# 2    2
# 3    1
# 4    2
# ..  ..
# 421  1
# 422  1
# 423  1
# 424  1
# 425  1
#
# [426 rows x 1 columns]
